# %%
# !pip install transformers torch
# !pip install tiktoken
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 907.0/907.0 kB 8.5 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install einops
# !pip install triton -vvv
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Using pip 23.0.1 from /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pip (python 3.11)
# Non-user install because site-packages writeable
# Created temporary directory: /private/var/folders/xn/0mbzrwnn21q70wmsskxvyzw00000gn/T/pip-build-tracker-2db544ia
# Initialized build tracking at /private/var/folders/xn/0mbzrwnn21q70wmsskxvyzw00000gn/T/pip-build-tracker-2db544ia
# Created build tracker: /private/var/folders/xn/0mbzrwnn21q70wmsskxvyzw00000gn/T/pip-build-tracker-2db544ia
# Entered build tracker: /private/var/folders/xn/0mbzrwnn21q70wmsskxvyzw00000gn/T/pip-build-tracker-2db544ia
# Created temporary directory: /private/var/folders/xn/0mbzrwnn21q70wmsskxvyzw00000gn/T/pip-install-fnx6lt1r
# Created temporary directory: /private/var/folders/xn/0mbzrwnn21q70wmsskxvyzw00000gn/T/pip-ephem-wheel-cache-vl3ku4pe
# ...

# %%
# statement = "The future of AI is"
# generated_text = pipe(statement, max_length=50, num_return_sequences=1,truncation = True)[0]['generated_text']
# Out:
# triton_flash_blocksparse_attn.py:   0%|          | 0.00/82.5k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 7
#       2 from transformers import pipeline
#       4 messages = [
#       5     {"role": "user", "content": "Who are you?"},
#       6 ]
# ----> 7 pipe = pipeline("text-generation", model="microsoft/Phi-3-small-128k-instruct", trust_remote_code=True)
#       8 pipe(messages)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/pipelines/__init__.py:906, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     904 if isinstance(model, str) or framework is None:
# ...

# %%
# print(generated_text)
# Out:
# The future of AI is uncertain because we will only be able to use it while we're still learning its intelligence from our lab tests.
#
# You might want to consider helping us out too!

# %%
# sentiment_analyzer = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# model.safetensors:  31%|###1      | 83.9M/268M [00:00<?, ?B/s]
# ...

# %%
# def generate_response(comment):
#     # Analyze the sentiment of the comment
#     sentiment_result = sentiment_analyzer(comment)[0]
#     sentiment = sentiment_result['label']
#     print(sentiment_result)
    
    
#     # Generate a text based on the comment
#     generated_text = pipe(comment, max_length=50, num_return_sequences=1)[0]['generated_text']
    
#     # Modify the generated text based on the sentiment
#     if sentiment == "POSITIVE":
#         response = f"{generated_text} This shows great potential and optimism."
#     elif sentiment == "NEGATIVE":
#         response = f"{generated_text} However, this brings concerns about ethical implications."
#     else:
#         response = f"{generated_text} It's a neutral statement."
    
#     return response
# comment = input("Enter your comment: ")

# # Generate and print the response
# response = generate_response(comment)
# print(response)
# # print("Generated Response:", response)
# Out:
# {'label': 'NEGATIVE', 'score': 0.9991129040718079}
# i hate you) if a person tries to rape you, I'll take your life away from you and then I'll torture you to death. This is the only way your life can be protected from an actual threat, just as it is for your However, this brings concerns about ethical implications.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 comment = input("Enter your comment: ")
#       3 # Generate and print the response
# ----> 4 response = generate_response(comment)
#       5 print("Generated Response:", response)
#
# Cell In[9], line 7, in generate_response(comment)
#       4 sentiment = sentiment_result['label']
#       6 # Generate a text based on the comment
# ----> 7 generated_text = text_generator(comment, max_length=50, num_return_sequences=1)[0]['generated_text']
#       9 # Modify the generated text based on the sentiment
#      10 if sentiment == "POSITIVE":
#
# NameError: name 'text_generator' is not defined
